# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline
from datetime import datetime
import seaborn as sns
import ELOTools as et

# %%
map_results = pd.read_csv('Match Summary Data.csv', index_col=0)

# %%
map_results[(map_results['Team A'] == "HOU") | (map_results['Team B'] == "HOU")].head(100)
# Out:
#          Date              Map Name  Map Number Map Type  Match Id Team A  \
# 0  2018-01-27               Numbani           1   Hybrid      2428    GLA
# 1  2018-01-27      Temple of Anubis           2  Assault      2428    GLA
# 2  2018-01-27                 Ilios           3     KOTH      2428    GLA
# 3  2018-01-27                Dorado           4   Escort      2428    GLA
# 0  2018-01-26               Numbani           1   Hybrid      2422    HOU
# 1  2018-01-26  Horizon Lunar Colony           2  Assault      2422    HOU
# 2  2018-01-26                 Ilios           3     KOTH      2422    HOU
# 3  2018-01-26            Junkertown           4   Escort      2422    HOU
# 0  2018-01-18            Junkertown           1   Escort      2408    DAL
# 1  2018-01-18  Horizon Lunar Colony           2  Assault      2408    DAL
# 2  2018-01-18                 Oasis           3     KOTH      2408    DAL
# 3  2018-01-18           Eichenwalde           4   Hybrid      2408    DAL
# 0  2018-01-18            Junkertown           1   Escort      2407    HOU
# 1  2018-01-18  Horizon Lunar Colony           2  Assault      2407    HOU
# 2  2018-01-18                 Oasis           3     KOTH      2407    HOU
# 3  2018-01-18               Numbani           4   Hybrid      2407    HOU
# 0  2018-01-13            Junkertown           1   Escort      2403    NYE
# 1  2018-01-13      Temple of Anubis           2  Assault      2403    NYE
# 2  2018-01-13                 Ilios           3     KOTH      2403    NYE
# 3  2018-01-13               Numbani           4   Hybrid      2403    NYE
# 0  2018-01-12                Dorado           1   Escort      2382    PHI
# 1  2018-01-12  Horizon Lunar Colony           2  Assault      2382    PHI
# 2  2018-01-12                 Oasis           3     KOTH      2382    PHI
# 3  2018-01-12           Eichenwalde           4   Hybrid      2382    PHI
# 4  2018-01-12         Lijiang Tower           5     KOTH      2382    PHI
#
#   Team B  Winner
# 0    HOU  Team B
# 1    HOU  Team B
# 2    HOU  Team B
# 3    HOU  Team B
# 0    FLA  Team A
# 1    FLA  Team A
# 2    FLA  Team A
# 3    FLA  Team A
# 0    HOU  Team B
# 1    HOU  Team B
# 2    HOU  Team B
# 3    HOU  Team B
# 0    SHD  Team A
# 1    SHD  Team A
# 2    SHD  Team A
# 3    SHD  Team A
# 0    HOU  Team B
# 1    HOU  Team A
# 2    HOU  Team A
# 3    HOU  Team A
# 0    HOU  Team A
# 1    HOU  Team B
# 2    HOU  Team A
# 3    HOU  Team B
# 4    HOU  Team A

# %%
test_df = map_results.copy()[['Date', 'Team A', 'Team B', 'Winner']]
test_df['Match of the Day'] = map_results.copy()['Map Number']
test_df.head()
# Out:
#          Date Team A Team B  Winner  Match of the Day
# 0  2018-01-27    GLA    HOU  Team B                 1
# 1  2018-01-27    GLA    HOU  Team B                 2
# 2  2018-01-27    GLA    HOU  Team B                 3
# 3  2018-01-27    GLA    HOU  Team B                 4
# 0  2018-01-27    VAL    FLA  Team A                 1

# %%
elo_df = et.compute_elo_table(test_df)

# %%
elo_df
# Out:
#            Date          Elo  Match Number Team
# 0    2018-01-10  1000.000000             0  SEO
# 1    2018-01-10  1000.000000             0  LDN
# 2    2018-01-10  1000.000000             0  PHI
# 3    2018-01-10  1000.000000             0  GLA
# 4    2018-01-10  1000.000000             0  DAL
# 5    2018-01-10  1000.000000             0  NYE
# 6    2018-01-10  1000.000000             0  HOU
# 7    2018-01-10  1000.000000             0  SHD
# 8    2018-01-10  1000.000000             0  VAL
# 9    2018-01-10  1000.000000             0  SFS
# 10   2018-01-10  1000.000000             0  BOS
# 11   2018-01-10  1000.000000             0  FLA
# 12   2018-01-11   990.000000             1  LDN
# 13   2018-01-11  1010.000000             1  FLA
# 14   2018-01-11  1010.000000             1  DAL
# 15   2018-01-11   990.000000             1  SEO
# 16   2018-01-11   990.000000             1  SHD
# 17   2018-01-11  1010.000000             1  GLA
# 18   2018-01-11   990.000000             1  SFS
# 19   2018-01-11  1010.000000             1  VAL
# 20   2018-01-11  1000.575011             2  LDN
# 21   2018-01-11   999.424989             2  FLA
# 22   2018-01-11   999.424989             2  DAL
# 23   2018-01-11  1000.575011             2  SEO
# 24   2018-01-11   980.575011             2  SHD
# 25   2018-01-11  1019.424989             2  GLA
# 26   2018-01-11   980.575011             2  SFS
# 27   2018-01-11  1019.424989             2  VAL
# 28   2018-01-11  1010.541911             3  LDN
# 29   2018-01-11   989.458089             3  FLA
# ..          ...          ...           ...  ...
# 290  2018-01-27   956.852497            23  DAL
# 291  2018-01-27  1006.722699            24  PHI
# 292  2018-01-27   956.889983            24  GLA
# 293  2018-01-27  1045.655493            24  VAL
# 294  2018-01-27   993.695287            24  BOS
# 295  2018-01-27  1088.620539            24  HOU
# 296  2018-01-27   950.962538            24  SFS
# 297  2018-01-27  1081.805200            24  NYE
# 298  2018-01-27   899.631310            24  FLA
# 299  2018-01-27   966.682987            24  DAL
# 300  2018-01-27   895.011763            24  SHD
# 301  2018-01-27  1099.306430            24  SEO
# 302  2018-01-27  1013.082262            25  PHI
# 303  2018-01-27   950.344877            25  GLA
# 304  2018-01-27  1051.987344            25  VAL
# 305  2018-01-27  1002.246217            25  BOS
# 306  2018-01-27  1094.838267            25  HOU
# 307  2018-01-27   941.132048            25  SFS
# 308  2018-01-27  1072.027463            25  NYE
# 309  2018-01-27   957.370850            25  DAL
# 310  2018-01-27   887.568933            25  SHD
# 311  2018-01-27  1088.522888            25  SEO
# 312  2018-01-27   999.128570            26  PHI
# 313  2018-01-27   944.127150            26  GLA
# 314  2018-01-27  1058.008045            26  VAL
# 315  2018-01-27   990.619618            26  BOS
# 316  2018-01-27  1082.811005            26  NYE
# 317  2018-01-27   985.873235            27  PHI
# 318  2018-01-27   999.931754            27  BOS
# 319  2018-01-27   993.316065            28  PHI
#
# [320 rows x 4 columns]

# %%
team_a_list = set(map_results["Team A"].unique())
team_b_list = set(map_results["Team B"].unique())
team_list = list(team_a_list.union(team_b_list))
team_list
# Out:
# ['SEO',
#  'LDN',
#  'PHI',
#  'GLA',
#  'DAL',
#  'NYE',
#  'HOU',
#  'SHD',
#  'VAL',
#  'SFS',
#  'BOS',
#  'FLA']

# %%
team_elo_dfs = {}
for team in team_list:
    temp_elo_df = elo_df[elo_df["Team"]==team]
    team_elo_dfs[team] = temp_elo_df

# %%
colors = {
    'LDN': '#78c9e5',
    'DAL': '#2f72c7',
    'SHD': '#000000',
    'SFS': '#e85609',
    'BOS': '#264b92',
    'PHI': '#f49d00',
    'SEO': '#a78a2c',
    'NYE': '#265ae1',
    'FLA': '#b50004',
    'VAL': '#eace00',
    'HOU': '#a1c861',
    'GLA': '#6d3eb9'
}
plt.figure(figsize=(12,12))
for key, value in team_elo_dfs.items():
    plt.plot(value['Match Number'], value['Elo'], label=key, marker='o', color=colors[key])
plt.xlim([0,30])
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,12))
for key, value in team_elo_dfs.items():
    plt.plot(value['Date'].str[-2:].astype(int), value['Elo'], label=key, marker='o', color=colors[key])
plt.xlim([10,30])
plt.legend()
plt.show()

# %%
test_str = '2018-01-11'

# %%
new_str = test_str[:-2] + str(int(test_str[-2:])-1)
new_str
# Out:
# '2018-01-10'
