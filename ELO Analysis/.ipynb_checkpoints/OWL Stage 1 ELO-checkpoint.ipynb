# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline
from datetime import datetime
import seaborn as sns

# %% [markdown]
# # Load match results

# %%
# %pwd
# Out:
# 'C:\\Users\\cbcastleberry\\Documents\\GitHub\\OWL\\ELO Analysis'

# %%
# %cd '/Users/calebcastleberry/Documents/Github/OWL/Data'
# Out:
# [WinError 3] The system cannot find the path specified: "'/Users/calebcastleberry/Documents/Github/OWL/Data'"
# C:\Users\cbcastleberry\Documents\GitHub\OWL\ELO Analysis

# %%
map_results = pd.read_csv('Match Summary Data.csv', index_col=0)

# %%
map_results = map_results.sort_values(by=['Date', 'Map Number'],ascending=True).reset_index(drop=True)
map_results.head(12)
# Out:
#           Date          Map Name  Map Number Map Type  Match Id Team A Team B  \
# 0   2018-01-11            Dorado           1   Escort      2381    LDN    FLA
# 1   2018-01-11        Junkertown           1   Escort      2380    DAL    SEO
# 2   2018-01-11            Dorado           1   Escort      2379    SHD    GLA
# 3   2018-01-11            Dorado           1   Escort      2375    SFS    VAL
# 4   2018-01-11  Temple of Anubis           2  Assault      2381    LDN    FLA
# 5   2018-01-11  Temple of Anubis           2  Assault      2380    DAL    SEO
# 6   2018-01-11  Temple of Anubis           2  Assault      2379    SHD    GLA
# 7   2018-01-11  Temple of Anubis           2  Assault      2375    SFS    VAL
# 8   2018-01-11             Oasis           3     KOTH      2381    LDN    FLA
# 9   2018-01-11             Ilios           3     KOTH      2380    DAL    SEO
# 10  2018-01-11             Ilios           3     KOTH      2379    SHD    GLA
# 11  2018-01-11             Ilios           3     KOTH      2375    SFS    VAL
#
#     Winner
# 0   Team B
# 1   Team A
# 2   Team B
# 3   Team B
# 4   Team A
# 5   Team B
# 6   Team B
# 7   Team B
# 8   Team A
# 9   Team B
# 10  Team B
# 11  Team B

# %%
map_results[(map_results["Team A"]=='GLA') | (map_results["Team B"]=='GLA')]
# Out:
#            Date              Map Name  Map Number Map Type  Match Id Team A  \
# 2    2018-01-11                Dorado           1   Escort      2379    SHD
# 6    2018-01-11      Temple of Anubis           2  Assault      2379    SHD
# 10   2018-01-11                 Ilios           3     KOTH      2379    SHD
# 14   2018-01-11           Eichenwalde           4   Hybrid      2379    SHD
# 25   2018-01-13            Junkertown           1   Escort      2404    SEO
# 31   2018-01-13  Horizon Lunar Colony           2  Assault      2404    SEO
# 37   2018-01-13                 Ilios           3     KOTH      2404    SEO
# 43   2018-01-13               Numbani           4   Hybrid      2404    SEO
# 65   2018-01-19            Junkertown           1   Escort      2410    PHI
# 67   2018-01-19      Temple of Anubis           2  Assault      2410    PHI
# 69   2018-01-19                 Ilios           3     KOTH      2410    PHI
# 71   2018-01-19               Numbani           4   Hybrid      2410    PHI
# 73   2018-01-19         Lijiang Tower           5     KOTH      2410    PHI
# 75   2018-01-20                Dorado           1   Escort      2415    GLA
# 81   2018-01-20  Horizon Lunar Colony           2  Assault      2415    GLA
# 87   2018-01-20                 Oasis           3     KOTH      2415    GLA
# 93   2018-01-20           Eichenwalde           4   Hybrid      2415    GLA
# 101  2018-01-25           Eichenwalde           1   Hybrid      2419    GLA
# 105  2018-01-25  Horizon Lunar Colony           2  Assault      2419    GLA
# 109  2018-01-25                 Ilios           3     KOTH      2419    GLA
# 113  2018-01-25            Junkertown           4   Escort      2419    GLA
# 117  2018-01-25         Lijiang Tower           5     KOTH      2419    GLA
# 127  2018-01-27               Numbani           1   Hybrid      2428    GLA
# 133  2018-01-27      Temple of Anubis           2  Assault      2428    GLA
# 139  2018-01-27                 Ilios           3     KOTH      2428    GLA
# 145  2018-01-27                Dorado           4   Escort      2428    GLA
#
#     Team B  Winner
# 2      GLA  Team B
# 6      GLA  Team B
# 10     GLA  Team B
# 14     GLA  Team B
# 25     GLA  Team A
# 31     GLA  Team A
# 37     GLA  Team A
# 43     GLA  Team A
# 65     GLA  Team A
# 67     GLA  Team A
# 69     GLA  Team B
# 71     GLA  Team B
# 73     GLA  Team B
# 75     NYE  Team B
# 81     NYE  Team B
# 87     NYE  Team B
# 93     NYE  Team B
# 101    VAL  Team A
# 105    VAL  Team A
# 109    VAL  Team B
# 113    VAL  Team B
# 117    VAL  Team B
# 127    HOU  Team B
# 133    HOU  Team B
# 139    HOU  Team B
# 145    HOU  Team B

# %% [markdown]
# # Create ELO Dataframe

# %%
team_list = list(map_results["Team A"].unique())
team_elo_start = []

# %%
team_a_list = set(map_results["Team A"].unique())
team_b_list = set(map_results["Team B"].unique())
team_list = list(team_a_list.union(team_b_list))
team_list
# Out:
# ['SHD',
#  'PHI',
#  'DAL',
#  'HOU',
#  'GLA',
#  'LDN',
#  'SEO',
#  'SFS',
#  'FLA',
#  'VAL',
#  'BOS',
#  'NYE']

# %%
for team in team_list:
    team_elo = {
        "date": datetime.strptime('2018-1-1', '%Y-%m-%d'),
        "team": team, 
        "elo": 1000,
        "map number": 0
    }
    team_elo_start.append(team_elo)

# %%
team_elo_start
# Out:
# [{'date': datetime.datetime(2018, 1, 1, 0, 0),
#   'elo': 1000,
#   'map number': 0,
#   'team': 'LDN'},
#  {'date': datetime.datetime(2018, 1, 1, 0, 0),
#   'elo': 1000,
#   'map number': 0,
#   'team': 'DAL'},
#  {'date': datetime.datetime(2018, 1, 1, 0, 0),
#   'elo': 1000,
#   'map number': 0,
#   'team': 'SHD'},
#  {'date': datetime.datetime(2018, 1, 1, 0, 0),
#   'elo': 1000,
#   'map number': 0,
#   'team': 'SFS'},
#  {'date': datetime.datetime(2018, 1, 1, 0, 0),
#   'elo': 1000,
#   'map number': 0,
#   'team': 'BOS'},
#  {'date': datetime.datetime(2018, 1, 1, 0, 0),
#   'elo': 1000,
#   'map number': 0,
#   'team': 'PHI'},
#  {'date': datetime.datetime(2018, 1, 1, 0, 0),
#   'elo': 1000,
#   'map number': 0,
#   'team': 'SEO'},
#  {'date': datetime.datetime(2018, 1, 1, 0, 0),
#   'elo': 1000,
#   'map number': 0,
#   'team': 'NYE'},
#  {'date': datetime.datetime(2018, 1, 1, 0, 0),
#   'elo': 1000,
#   'map number': 0,
#   'team': 'FLA'},
#  {'date': datetime.datetime(2018, 1, 1, 0, 0),
#   'elo': 1000,
#   'map number': 0,
#   'team': 'VAL'},
#  {'date': datetime.datetime(2018, 1, 1, 0, 0),
#   'elo': 1000,
#   'map number': 0,
#   'team': 'HOU'},
#  {'date': datetime.datetime(2018, 1, 1, 0, 0),
#   'elo': 1000,
#   'map number': 0,
#   'team': 'GLA'}]

# %%
elo_df = pd.DataFrame(team_elo_start)

# %%
elo_df.head(12)
# Out:
#          date   elo  map number team
# 0  2018-01-01  1000           0  LDN
# 1  2018-01-01  1000           0  DAL
# 2  2018-01-01  1000           0  SHD
# 3  2018-01-01  1000           0  SFS
# 4  2018-01-01  1000           0  BOS
# 5  2018-01-01  1000           0  PHI
# 6  2018-01-01  1000           0  SEO
# 7  2018-01-01  1000           0  NYE
# 8  2018-01-01  1000           0  FLA
# 9  2018-01-01  1000           0  VAL
# 10 2018-01-01  1000           0  HOU
# 11 2018-01-01  1000           0  GLA

# %% [markdown]
# # Elo Function

# %%
test_elo_a = 1200
test_elo_b = 1100

# %%
def elo_probabilities(elo_a, elo_b):
    q_a = 10**(elo_a/400)
    q_b = 10**(elo_b/400)
    e_a = q_a / (q_a + q_b)
    e_b = q_b / (q_a + q_b)
    return e_a, e_b

def update_elo(elo_a, elo_b, a_win, K=20):
    q_a = 10**(elo_a/400)
    q_b = 10**(elo_b/400)
    e_a = q_a / (q_a + q_b)
    e_b = q_b / (q_a + q_b)
    
    
    r_a = elo_a + K * (a_win - e_a)
    r_b = elo_b + K * ((1-a_win) - e_b)
    return r_a, r_b

# %%
elo_probabilities(test_elo_a, test_elo_b)
# Out:
# (0.6400649998028851, 0.35993500019711494)

# %%
update_elo(test_elo_a, test_elo_b, 1)
# Out:
# (1207.1987000039423, 1092.8012999960577)

# %%
update_elo(test_elo_a, test_elo_b, 0)
# Out:
# (1187.1987000039423, 1112.8012999960577)

# %% [markdown]
# ## Get current elo

# %%
def get_current_elo(df, team, date):
    df = df[(df["team"]== team) & (df['date'] <= date) ]
    df = df.sort_values(by=['date', 'map number'], ascending=False).reset_index(drop=True)
    elo = df.iloc[0]['elo']
    return elo

def get_current_map_number(df, team, date):
    df = df[(df["team"]== team) & (df['date'] <= date) ]
    df = df.sort_values(by='map number', ascending=False).reset_index(drop=True)
    elo = df.iloc[0]['map number']
    return elo

# %%
print(get_current_elo(elo_df, 'SEO', datetime.strptime('2018-1-2', '%Y-%m-%d')))
get_current_map_number(elo_df, "SEO", datetime.strptime('2018-1-2', '%Y-%m-%d'))
# Out:
# 1000
# 0

# %% [markdown]
# # Loop through map result frame and update elo

# %%
current_map =  map_results.iloc[0]
current_map
# Out:
# Date          2018-01-11
# Map Name          Dorado
# Map Number             1
# Map Type          Escort
# Match Id            2381
# Team A               LDN
# Team B               FLA
# Winner            Team B
# Name: 0, dtype: object

# %%
map_results.shape[0]
# Out:
# 154

# %%
for i in range(map_results.shape[0]):
    current_map = map_results.iloc[i]
    map_name = current_map['Map Name']
    team_a = current_map['Team A']
    team_b = current_map['Team B']
    match_date = datetime.strptime(current_map['Date'], '%Y-%m-%d')
    winner = current_map['Winner']
    if winner=='Team A':
        a_win = 1
    elif winner=='Team B':
        a_win = 0
    else:
        a_win = 0.5
        
    a_elo = get_current_elo(elo_df, team_a, match_date)
    b_elo = get_current_elo(elo_df, team_b, match_date)
    a_map = get_current_map_number(elo_df, team_a, match_date) + 1
    b_map = get_current_map_number(elo_df, team_b, match_date) + 1
    new_a_row = {
        'date': match_date,
        'team': team_a,
        'map number': a_map
    }
    new_b_row = {
        'date': match_date,
        'team': team_b,
        'map number': b_map
    }
    new_a_row['elo'], new_b_row['elo'] = update_elo(a_elo, b_elo, a_win=a_win, K=20)
    temp_df = pd.DataFrame([new_a_row, new_b_row])
    #print(temp_df.head())
    elo_df = pd.concat([elo_df, temp_df])
    #print(elo_df.tail())
    #print(map_name, i, team_a, a_elo, team_b, b_elo, a_win, match_date)
    #print(new_a_row)
    #print(new_b_row)

# %%
elo_df.sort_values(by='date',ascending=False).iloc[0]
# Out:
# date          2018-01-27 00:00:00
# elo                       1082.81
# map number                     26
# team                          NYE
# Name: 1, dtype: object

# %%
elo_df = elo_df.sort_values(by=['date', 'map number'], ascending=False).reset_index(drop=True)

# %%
elo_df.head()
# Out:
#         date         elo  map number team
# 0 2018-01-27  993.316065          28  PHI
# 1 2018-01-27  985.873235          27  PHI
# 2 2018-01-27  999.931754          27  BOS
# 3 2018-01-27  999.128570          26  PHI
# 4 2018-01-27  944.127150          26  GLA

# %%
elo_df['day map'] = elo_df['date'].apply(lambda x: x.day) + .02 * elo_df['map number']

# %%
team_elo_dfs = {}
for team in team_list:
    temp_elo_df = elo_df[elo_df["team"]==team]
    team_elo_dfs[team] = temp_elo_df

# %%
SHD_elo = elo_df[elo_df["team"]=='SHD']
SHD_elo
# Out:
#           date          elo  map number team  day map
# 16  2018-01-27   887.568933          25  SHD    27.50
# 27  2018-01-27   895.011763          24  SHD    27.48
# 36  2018-01-27   881.756427          23  SHD    27.46
# 43  2018-01-27   867.802736          22  SHD    27.44
# 47  2018-01-27   874.162299          21  SHD    27.42
# 90  2018-01-25   880.860956          20  SHD    25.40
# 97  2018-01-25   864.638594          19  SHD    25.38
# 104 2018-01-25   868.556382          18  SHD    25.36
# 106 2018-01-25   872.623797          17  SHD    25.34
# 119 2018-01-20   876.851191          16  SHD    20.32
# 128 2018-01-20   885.135053          15  SHD    20.30
# 138 2018-01-20   893.913210          14  SHD    20.28
# 147 2018-01-20   903.222203          13  SHD    20.26
# 187 2018-01-18   913.098633          12  SHD    18.24
# 194 2018-01-18   919.952840          11  SHD    18.22
# 201 2018-01-18   927.401505          10  SHD    18.20
# 206 2018-01-18   935.519994           9  SHD    18.18
# 219 2018-01-13   944.389851           8  SHD    13.16
# 231 2018-01-13   953.845937           7  SHD    13.14
# 243 2018-01-13   963.879037           6  SHD    13.12
# 253 2018-01-13   953.304026           5  SHD    13.10
# 280 2018-01-11   963.304026           4  SHD    11.08
# 288 2018-01-11   971.688566           3  SHD    11.06
# 296 2018-01-11   980.575011           2  SHD    11.04
# 304 2018-01-11   990.000000           1  SHD    11.02
# 310 2018-01-01  1000.000000           0  SHD     1.00

# %% [markdown]
# ## Analysis

# %%
plt.plot(SHD_elo['day map'], SHD_elo['elo'], label='SHD', marker='o')
plt.xlim([0,30])
plt.legend()
plt.show()

# %%
colors = {
    'LDN': '#78c9e5',
    'DAL': '#2f72c7',
    'SHD': '#000000',
    'SFS': '#e85609',
    'BOS': '#264b92',
    'PHI': '#f49d00',
    'SEO': '#a78a2c',
    'NYE': '#265ae1',
    'FLA': '#b50004',
    'VAL': '#eace00',
    'HOU': '#a1c861',
    'GLA': '#6d3eb9'
}
plt.figure(figsize=(12,12))
for key, value in team_elo_dfs.items():
    plt.plot(value['map number'], value['elo'], label=key, marker='o', color=colors[key])
plt.xlim([0,30])
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,12))
for key, value in team_elo_dfs.items():
    plt.plot(value['day map'], value['elo'], label=key, marker='o', color=colors[key])
plt.xlim([0,30])
plt.legend()
plt.show()
