# %%
import pandas as pd
#from selenium import webdriver
import time
from bs4 import BeautifulSoup
from pprint import pprint
import requests

# %%
import MatchStats as ms

# %%
MATCH_LIST_URL = "https://www.winstonslab.com/events/event.php?id=86#matches"

# %%
response = requests.get(MATCH_LIST_URL)
html = BeautifulSoup(response.text, "lxml")

# %%
past_div = html.find("div", {"id": "past"})

# %%
table_body = past_div.find("table").find("tbody")

# %%
rows = table_body.findAll("tr")

# %% [markdown]
# ## Starting here we are working with an individual match

# %%
test_row = rows[1]

# %%
match_link = test_row.td.a
match_link
# Out:
# <a href="/matches/match.php?id=2403" id="tzDate_232"> 21:00 - Jan 13, 2018 </a>

# %% [markdown]
# Boom! thats the link we want.

# %%
match_id = match_link.attrs["href"].split("=")[-1]

# %% [markdown]
# There's the match id

# %%
df_2403 = ms.detailed_match_data(2403)

# %%
df_2403.head(10)
# Out:
#    Match ID      Player         Hero      Time Rating   FWin%     PTK   K/10  \
# 0      2403      JJoNak     Zenyatta  00:47:21   1276  50.91%   12.5%   4.86
# 1      2403  Saebyeolbe       Tracer  00:32:17   1174  52.63%  28.15%  11.77
# 2      2403      Libero  Soldier: 76  00:07:17   1058  71.43%  27.59%  10.98
# 3      2403   clockwork       Tracer  00:16:37   1055     30%  31.25%   9.03
# 4      2403        Bani        Mercy  00:47:55   1041  49.12%   0.65%   0.21
# 5      2403        MekO      Roadhog  00:06:50   1039  28.57%     25%   7.32
# 6      2403        Mano      Winston  00:21:30   1037  38.46%  18.42%   6.51
# 7      2403      Libero        Genji  00:16:21   1036  47.37%   20.9%   8.56
# 8      2403         ArK        Mercy  00:47:23   1035  49.12%   0.56%   0.21
# 9      2403  Saebyeolbe       Mccree  00:07:26   1002     60%  26.92%   9.42
#
#    D/10  U/10     ...          UE    UOOF   FK   FD Impact Elim/10 dmg/10  \
# 0  4.44  4.01     ...        13.8  10.53%   7%  11%    762     N/A    N/A
# 1  4.65  5.27     ...       31.98      0%  11%   8%   1265     N/A    N/A
# 2  5.49  4.12     ...       28.57      0%  14%  29%    635     N/A    N/A
# 3  6.62  5.42     ...      -15.71      0%  10%   5%   1293     N/A    N/A
# 4  5.01  3.97     ...        0.88      0%   0%   4%   1403     N/A    N/A
# 5  7.32  2.93     ...      -28.57      0%  14%   0%   1438     N/A    N/A
# 6  6.51  3.26     ...       11.54  14.29%   0%   8%   1328     N/A    N/A
# 7   5.5  3.67     ...        19.3      0%  11%   5%    935     N/A    N/A
# 8  4.22   3.8     ...       29.45   5.88%   0%   7%    653     N/A    N/A
# 9  4.04  2.69     ...          40     50%   0%  10%    714     N/A    N/A
#
#   heal/10 ObjTime/10 ObjKills/10
# 0     N/A        N/A         N/A
# 1     N/A        N/A         N/A
# 2     N/A        N/A         N/A
# 3     N/A        N/A         N/A
# 4     N/A        N/A         N/A
# 5     N/A        N/A         N/A
# 6     N/A        N/A         N/A
# 7     N/A        N/A         N/A
# 8     N/A        N/A         N/A
# 9     N/A        N/A         N/A
#
# [10 rows x 22 columns]

# %% [markdown]
# ## Now let's try to loop through all of the matches

# %%
columns = df_2403.columns.values

# %%
base_df = pd.DataFrame(columns=columns, index=[])

# %%
for row in rows:
    match_link = row.td.a
    match_id = match_link.attrs["href"].split("=")[-1]
    match_df = ms.detailed_match_data(match_id)
    base_df = base_df.append(match_df, ignore_index=True)
    print("Finished Match: {}".format(match_id))
# Out:
# Finished Match: 2404
# Finished Match: 2403
# Finished Match: 2402
# Finished Match: 2401
# Finished Match: 2400
# Finished Match: 2399
# Finished Match: 2383
# Finished Match: 2382
# Finished Match: 2381
# Finished Match: 2380
# Finished Match: 2379
# Finished Match: 2375

# %%
base_df.shape
# Out:
# (694, 22)

# %%
base_df.head(10)
# Out:
#   Match ID     Player        Hero      Time Rating   FWin%     PTK   K/10  \
# 0     2404      Fleta  Widowmaker  00:22:53   1476  61.54%  39.78%  16.17
# 1     2404     Wekeed     Junkrat  00:17:40   1229  68.18%  32.56%  15.85
# 2     2404   Surefour      Tracer  00:05:40   1218   62.5%  27.78%   8.82
# 3     2404  ryujehong    Zenyatta  00:31:30   1177  62.16%  12.06%    5.4
# 4     2404      zunba        D.Va  00:44:42   1128  58.93%   20.4%   9.17
# 5     2404      Fleta      Reaper  00:06:34   1118  66.67%  35.71%  15.23
# 6     2404   BigG00se       Lucio  00:16:04   1104     35%  10.34%   3.73
# 7     2404       tobi       Mercy  00:43:37   1056  59.62%   0.53%   0.23
# 8     2404       KuKi     Winston  00:43:33   1039  58.18%  13.85%    6.2
# 9     2404   Surefour      Pharah  00:05:04   1036  28.57%  26.32%   9.87
#
#    D/10  U/10     ...         UE   UOOF   FK   FD Impact Elim/10 dmg/10  \
# 0  4.37  4.81     ...      18.46  9.09%  58%   0%   1565     N/A    N/A
# 1  6.79  3.96     ...      31.82     0%  27%   5%   1479     N/A    N/A
# 2  5.29  7.06     ...       4.17     0%  13%  13%   1800     N/A    N/A
# 3  5.71  3.49     ...      -6.61    10%   3%  14%    824     N/A    N/A
# 4  5.37     0     ...          0     0%   5%   0%    859     N/A    N/A
# 5  7.61  4.57     ...          0     0%  50%  17%   1118     N/A    N/A
# 6   5.6  3.11     ...         15     0%   5%   0%   1020     N/A    N/A
# 7  4.13   3.9     ...      16.86  5.88%   0%   4%   1464     N/A    N/A
# 8   6.2   3.9     ...       4.32  5.88%   0%   5%   1095     N/A    N/A
# 9  5.92  1.97     ...          0     0%   0%  14%   1232     N/A    N/A
#
#   heal/10 ObjTime/10 ObjKills/10
# 0     N/A        N/A         N/A
# 1     N/A        N/A         N/A
# 2     N/A        N/A         N/A
# 3     N/A        N/A         N/A
# 4     N/A        N/A         N/A
# 5     N/A        N/A         N/A
# 6     N/A        N/A         N/A
# 7     N/A        N/A         N/A
# 8     N/A        N/A         N/A
# 9     N/A        N/A         N/A
#
# [10 rows x 22 columns]

# %%
base_df.tail(10)
# Out:
#     Match ID      Player         Hero      Time Rating   FWin%     PTK   K/10  \
# 684     2375       Kariv  Soldier: 76  00:00:03    NED      0%      0%      0
# 685     2375      Sleepy          Ana  00:01:42    NED     50%      0%      0
# 686     2375      Sleepy        Moira  00:00:41    NED      0%      0%      0
# 687     2375      Sleepy        Zarya  00:00:10    NED      0%      0%      0
# 688     2375      Danteh        Genji  00:02:33    NED     50%   9.09%   3.92
# 689     2375  silkthread        Genji  00:03:17    NED     75%  19.05%  12.18
# 690     2375  silkthread       Mccree  00:02:31    NED      0%     50%   3.97
# 691     2375  silkthread       Pharah  00:03:27    NED     75%  27.27%    8.7
# 692     2375  silkthread       Tracer  00:02:53    NED    100%   12.5%   6.94
# 693     2375        Envy      Bastion  00:00:50    NED  66.67%      0%      0
#
#       D/10  U/10     ...       UE UOOF   FK   FD Impact Elim/10 dmg/10  \
# 684      0     0     ...        0   0%   0%   0%    996     N/A    N/A
# 685   5.88  5.88     ...      -50   0%   0%   0%   1135     N/A    N/A
# 686  29.27     0     ...        0   0%   0%   0%   1024     N/A    N/A
# 687      0     0     ...        0   0%   0%   0%    995     N/A    N/A
# 688   7.84  3.92     ...       50   0%  25%   0%   1366     N/A    N/A
# 689   3.05  6.09     ...       25   0%   0%   0%   1408     N/A    N/A
# 690  15.89  3.97     ...      100   0%   0%  33%    311     N/A    N/A
# 691    2.9   5.8     ...      -25   0%   0%   0%   1094     N/A    N/A
# 692   3.47  10.4     ...        0  50%   0%   0%    672     N/A    N/A
# 693      0     0     ...        0   0%   0%   0%    986     N/A    N/A
#
#     heal/10 ObjTime/10 ObjKills/10
# 684     N/A        N/A         N/A
# 685     N/A        N/A         N/A
# 686     N/A        N/A         N/A
# 687     N/A        N/A         N/A
# 688     N/A        N/A         N/A
# 689     N/A        N/A         N/A
# 690     N/A        N/A         N/A
# 691     N/A        N/A         N/A
# 692     N/A        N/A         N/A
# 693     N/A        N/A         N/A
#
# [10 rows x 22 columns]

# %%
base_df.to_csv("detailed_stats.csv")

# %%
base_df.columns.values
# Out:
# array(['Match ID', 'Player', 'Hero', 'Time', 'Rating', 'FWin%', 'PTK',
#        'K/10', 'D/10', 'U/10', 'TTCU', 'KPU', 'UE', 'UOOF', 'FK', 'FD',
#        'Impact', 'Elim/10', 'dmg/10', 'heal/10', 'ObjTime/10',
#        'ObjKills/10'], dtype=object)
